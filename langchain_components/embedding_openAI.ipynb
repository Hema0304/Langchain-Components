# %%
import os
from dotenv import load_dotenv
load_dotenv() #load all environment variables from .env file
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
#embeddings = OpenAIEmbeddings(model="text-embedding-3-small",dimensions=1024) #specify dimensions if you want to use a custom embedding model
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x0000027C4F47FB50>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x0000027C50A2FA00>, model='text-embedding-3-small', dimensions=None, deployment='text-embedding-ada-002', openai_api_version=None, openai_api_base=None, openai_api_type=None, openai_proxy=None, embedding_ctx_length=8191, openai_api_key=SecretStr('**********'), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)

# %%
text = "This is a test document for embedding generation."
query_embedding = embeddings.embed_query(text)
query_embedding
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 text = "This is a test document for embedding generation."
# ----> 2 query_embedding = embeddings.embed_query(text)
#       3 query_embedding
#
# File c:\LANGCHAIN\venv\lib\site-packages\langchain_openai\embeddings\base.py:801, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     791 """Call out to OpenAI's embedding endpoint for embedding query text.
#     792
#     793 Args:
#    (...)
#     798     Embedding for the text.
#     799 """
#     800 self._ensure_sync_client_available()
# --> 801 return self.embed_documents([text], **kwargs)[0]
#
# File c:\LANGCHAIN\venv\lib\site-packages\langchain_openai\embeddings\base.py:751, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     748 # Unconditionally call _get_len_safe_embeddings to handle length safety.
# ...

# %%
query_embedding[0]
len(query_embedding)

# %%
from langchain_community.document_loaders import TextLoader

loder = TextLoader('speech.txt')
documents = loder.load()
documents
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Artificial Intelligence (AI) refers to the simulation of human intelligence in machines that are programmed to think and learn. These systems can perform tasks such as problem-solving, decision-making, and language understanding.\n\nMachine Learning is a subset of AI that allows systems to learn from data without being explicitly programmed. It uses algorithms to identify patterns and improve performance over time.\n\nDeep Learning, a further subset of Machine Learning, uses neural networks with multiple layers to analyze complex patterns in data. It is widely used in image recognition, speech processing, and natural language processing.')]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=10, chunk_overlap=0)
texts = text_splitter.split_documents(documents)
texts
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Artificial'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Intellige'),
#  Document(metadata={'source': 'speech.txt'}, page_content='nce'),
#  Document(metadata={'source': 'speech.txt'}, page_content='(AI)'),
#  Document(metadata={'source': 'speech.txt'}, page_content='refers to'),
#  Document(metadata={'source': 'speech.txt'}, page_content='the'),
#  Document(metadata={'source': 'speech.txt'}, page_content='simulatio'),
#  Document(metadata={'source': 'speech.txt'}, page_content='n'),
#  Document(metadata={'source': 'speech.txt'}, page_content='of human'),
#  Document(metadata={'source': 'speech.txt'}, page_content='intellige'),
#  Document(metadata={'source': 'speech.txt'}, page_content='nce'),
#  Document(metadata={'source': 'speech.txt'}, page_content='in'),
#  Document(metadata={'source': 'speech.txt'}, page_content='machines'),
#  Document(metadata={'source': 'speech.txt'}, page_content='that are'),
# ...

# %%
#vector embeddings and vector storeDB
from langchain_community.vectorstores import Chroma

db =    Chroma.from_documents(texts, embeddings)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[8], line 4
#       1 #vector embeddings and vector storeDB
#       2 from langchain_community.vectorstores import Chroma
# ----> 4 db =    Chroma.from_documents(texts, embeddings)
#
# File c:\LANGCHAIN\venv\lib\site-packages\langchain_community\vectorstores\chroma.py:887, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     885 texts = [doc.page_content for doc in documents]
#     886 metadatas = [doc.metadata for doc in documents]
# --> 887 return cls.from_texts(
#     888     texts=texts,
#     889     embedding=embedding,
#     890     metadatas=metadatas,
#     891     ids=ids,
#     892     collection_name=collection_name,
#     893     persist_directory=persist_directory,
# ...

# %%
#retrived the results from the vector storeDB
query= " Machine Learning is a subset of AI"
retrived_resilts = db.similarity_search(query)
retrived_resilts
